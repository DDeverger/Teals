# %% [markdown]
# # Intro to Python
# -[Input and Output](#input-and-Output)
# -[Python Variables](#Python-Variables)
# -[Arithmetic and Boolean Operators](#Arithmetic-and-Boolean-Operators)

# %% [markdown]
# ## Input and Output

# %%
input()
# Out:
#  Hi there
# 'Hi there'

# %%
input("Please type your name")
# Out:
# Please type your name Kyuu
# 'Kyuu'

# %%
print("Hi there")
# Out:
# Hi there

# %%
print("programming""is""intersting")
# Out:
# programmingisintersting

# %%
print("programming", "is", "intersting")
# Out:
# programming is intersting

# %%
print("programming is intersting")
# Out:
# programming is intersting

# %% [markdown]
# ## Python Variables

# %%
yo="About me"
name="Kyuu"
school="towers high school"
interest="Gaming, Anime, Programming"
age=17

# %%
print(interest)
# Out:
# Gaming, Anime, Programming

# %%
print(name)
# Out:
# Kyuu

# %%
print(age)
# Out:
# 17

# %%
name=input("type your name here")
# Out:
# type your name here Kyuu

# %%
print(name)
# Out:
# Kyuu

# %% [markdown]
# ## Arithmetic and Boolean Operators

# %%
5+7
# Out:
# 12

# %%
1000000000+55876586954867489358458983
# Out:
# 55876586954867490358458983

# %%
5-68868686
# Out:
# -68868681

# %%
548925489584*1
# Out:
# 548925489584

# %%
10/10
# Out:
# 1.0

# %%
7*7
# Out:
# 49

# %%
55/7
# Out:
# 7.857142857142857

# %%
31001001010010010012010010101010101+110101010101010100000101010
# Out:
# 31001001120111020113020110101111111

# %%
7+25/5+4
# Out:
# 16.0

# %%
1+2+1+2+1+3+3-4/5/2/5/2/7+1+1-3
# Out:
# 11.994285714285715

# %%
"a"+"a"
# Out:
# 'aa'

# %%
print(10>5)
# Out:
# True

# %%
print(10>1000)
# Out:
# False
